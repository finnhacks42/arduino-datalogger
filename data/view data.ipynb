# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("raw_data_201909092124.csv",names=['humid','temp'])
df.head()
# Out:
#    humid  temp
# 0    NaN  20.0
# 1   50.2  20.0
# 2   50.2  20.0
# 3   50.3  20.0
# 4   50.3  20.0

# %%
plt.plot(df['humid'])

# %%
plt.plot(df['temp'])
